# %%
import pandas as pd
from IPython.display import clear_output

dfs = []
for txt in ['2018.txt', '2019.txt', '2020.txt','2021.txt']:
    df = pd.read_csv(txt, delimiter=';', encoding = 'cp1252')
    df.columns = ['COD_FILIAL', 'SIGLA', 'NOME', 'REGIAO', 'COD_PRODUTO', 'PRODUTO', 'COD_GRUPO', 'CLASSIFICACAO', 'QTD_VENDIDA', 'DATA', 'COD_FILIAL_', 'COD_ENTREGA', 'ENTREGA', 'ANO/MES', 'MES', '1', '2', 'CD', '3', '4', 'SUBCATEGORIA', 'FORNECEDOR']
    df['DATA'] = pd.to_datetime(df['DATA'], dayfirst=True)
    dfs.append(df)
df = pd.concat(dfs) 

df
# Out:
# /Users/david/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/david/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         COD_FILIAL SIGLA        NOME   REGIAO  COD_PRODUTO  \
# 0               19   ICO         Ico   SERTAO        23161
# 1               21   JCB    Jacobina    BAHIA        19405
# 2               13   JPL       Lagoa  LITORAL        24575
# 3               13   JPL       Lagoa  LITORAL        24555
# 4               19   ICO         Ico   SERTAO        22929
# ...            ...   ...         ...      ...          ...
# 203872          13   JPL       Lagoa  LITORAL        27251
# 203873          28   JP5  Sto. Elias  LITORAL        27248
# 203874          28   JP5  Sto. Elias  LITORAL        27249
# 203875          35   SRT   Sta. Rita  LITORAL        27251
# 203876          48   MTO    Monteiro    BREJO        27251
#
#                                             PRODUTO  COD_GRUPO  \
# 0       CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4          3
# 1                            REFRIGERADOR ROC 31 BR          3
# 2             TELEVISOR SMART 32" 32PHG5102 PHILIPS          5
# 3           TELEVISOR SMART 32" PH32E20DSGWA PHILCO          5
# 4          UNIDADE EVAPORADORA 12000BTUS 42MACA12S5          3
# ...                                             ...        ...
# 203872                                  CAPINHA A31       1002
# 203873                                CAPINHA  A21S       1002
# 203874                                 CAPINHA A10S       1002
# 203875                                  CAPINHA A31       1002
# 203876                                  CAPINHA A31       1002
#
#                                  CLASSIFICACAO  QTD_VENDIDA       DATA  ...  \
# 0       ELETRO AR E VENTILACAO AR CONDICIONADO           27 2018-02-27  ...
# 1          ELETRO ELETRODOMESTICO REFRIGERADOR           29 2018-02-05  ...
# 2               TECNOLOGIA TV E VIDEO SMART TV           16 2018-02-23  ...
# 3               TECNOLOGIA TV E VIDEO SMART TV           17 2018-02-28  ...
# 4       ELETRO AR E VENTILACAO AR CONDICIONADO           22 2018-02-27  ...
# ...                                        ...          ...        ...  ...
# 203872             CELULAR ACESSORIO ACESSORIO            1 2021-01-04  ...
# 203873             CELULAR ACESSORIO ACESSORIO            1 2021-01-04  ...
# 203874             CELULAR ACESSORIO ACESSORIO            1 2021-01-04  ...
# 203875             CELULAR ACESSORIO ACESSORIO            2 2021-01-04  ...
# 203876             CELULAR ACESSORIO ACESSORIO            1 2021-01-04  ...
#
#                       ENTREGA  ANO/MES        MES         1     2   CD  \
# 0              Pega/Não Monta   201802  FEVEREIRO       NaN  2018  CJZ
# 1              Pega/Não Monta   201802  FEVEREIRO       NaN  2018  CJZ
# 2       Não Entrega/Não Monta   201802  FEVEREIRO       NaN  2018  CBO
# 3       Não Entrega/Não Monta   201802  FEVEREIRO       NaN  2018  CBO
# 4              Pega/Não Monta   201802  FEVEREIRO       NaN  2018  CJZ
# ...                       ...      ...        ...       ...   ...  ...
# 203872  Não Entrega/Não Monta   202101    JANEIRO  VENDAWEB  2021  CBO
# 203873  Não Entrega/Não Monta   202101    JANEIRO  VENDAWEB  2021  CBO
# 203874  Não Entrega/Não Monta   202101    JANEIRO  VENDAWEB  2021  CBO
# 203875  Não Entrega/Não Monta   202101    JANEIRO  VENDAWEB  2021  CBO
# 203876  Não Entrega/Não Monta   202101    JANEIRO  VENDAWEB  2021  CBO
#
#                3                      4         SUBCATEGORIA       FORNECEDOR
# 0       19023161     1902316127/02/2018  ELETRO LINHA BRANCA         VENTISOL
# 1       21019405     2101940505/02/2018  ELETRO LINHA BRANCA         ESMALTEC
# 2       13024575     1302457523/02/2018      ELETRO TV E SOM  ENVISION MANAUS
# 3       13024555     1302455528/02/2018      ELETRO TV E SOM           PHILCO
# 4       19022929     1902292927/02/2018  ELETRO LINHA BRANCA         CLIMAZON
# ...          ...                    ...                  ...              ...
# 203872  13027251  1302725144200VENDAWEB              CELULAR             SIRI
# 203873  28027248  2802724844200VENDAWEB              CELULAR             SIRI
# 203874  28027249  2802724944200VENDAWEB              CELULAR             SIRI
# 203875  35027251  3502725144200VENDAWEB              CELULAR             SIRI
# 203876  48027251  4802725144200VENDAWEB              CELULAR             SIRI
#
# [3886665 rows x 22 columns]

# %%
#df = df.sort_values(by='DATA', ascending=True)
print(df.loc[df['SUBCATEGORIA'] == 'ELETRO LINHA BRANCA']['COD_GRUPO'].unique())
for cat in df['PRODUTO'].unique():
    u = df.loc[df['PRODUTO'] == cat]['FORNECEDOR'].unique()
    if(len(u) > 1):
        print(cat, u)
print(df.loc[df['CLASSIFICACAO'] == 'ELETRO ELETRODOMESTICO REFRIGERADOR']['SUBCATEGORIA'].unique())
#df.head(2)
# Out:
# [3]
# CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4 ['VENTISOL' 'VENTISOL            ']
# REFRIGERADOR ROC 31 BR ['ESMALTEC' 'ESMALTEC            ']
# TELEVISOR SMART 32" 32PHG5102 PHILIPS ['ENVISION MANAUS' 'ENVISION MANAUS     ']
# TELEVISOR SMART 32" PH32E20DSGWA PHILCO ['PHILCO' 'PHILCO              ']
# UNIDADE EVAPORADORA 12000BTUS 42MACA12S5 ['CLIMAZON' 'CLIMAZON            ']
# TELEVISOR SMART 32" KDL-32W655D SONY ['SONY' 'SONY                ']
# TELEVISOR SMART 43" 43PFG5102 PHILIPS ['ENVISION MANAUS' 'ENVISION MANAUS     ']
# UNIDADE CONDENSADORA 12000BTUS 38KCX12S5 ['CLIMAZON' 'CLIMAZON            ']
# TELEVISOR 40" L40D2900 SEMP TCL ['SEMP TCL' 'SEMP TCL            ']
# TELEVISOR SMART 43" L43S4900FS SEMP TCL ['SEMP TCL' 'SEMP TCL            ']
# TELEVISOR SMART 48" KDL-48W655D SONY ['SONY' 'SONY                ']
# TELEVISOR SMART 43" 43LJ5550 LG ['LG' 'LG                  ']
# TELEVISOR SMART 42" PH42F10DSGWAC PHILCO ['PHILCO' 'PHILCO              ']
# TABLET NB269 M7 3G PLUS PRETO ['MULTILASER' 'MULTILASER          ']
# LAVADORA AUTOMATICA NA-F160 B5WB PANASONIC ['PANASONIC' 'PANASONIC           ']
# COLC KING BEST 30CMX198CMX158 M.SUPER LASTIC ['SFERA - PB' 'SFERA - PB          ']
# TELEVISOR SMART 49" TC49ES630 PANASONIC ['PANASONIC' 'PANASONIC           ']
# SMARTPHONE LG K10 NOVO DB TITANIUM ['LG' 'LG                  ']
# TELEVISOR 32" KDL-32R305B SONY ['SONY' 'SONY                ']
# FOGAO 4BC. BALI 4076 BR ['ESMALTEC' 'ESMALTEC            ']
# TELEVISOR SMART 49" UN49J5200 SAMSUNG ['SAMSUNG' 'SAMSUNG             ']
# VENTILADOR VFM2 SIL FORCE VE3230B4 ['SEB COMERCIAL' 'SEB COMERCIAL       ']
# TELEVISOR 40" TC40D400B PANASONIC ['PANASONIC' 'PANASONIC           ']
# SMARTPHONE LG K10 NOVO DB DOURADO ['LG' 'LG                  ']
# SMARTPHONE LG K10 POWER DB DOURADO ['LG' 'LG                  ']
# COLC KING BEST 30CMX188CMX138 M.SUPER LASTIC ['SFERA - PB' 'SFERA - PB          ']
# FREEZER HORIZONTAL EFH 500 220V BR ['ESMALTEC' 'ESMALTEC            ']
# REFRIGERADOR NR-BT40BD1WB 387L BCO ['PANASONIC' 'PANASONIC           ']
# TELEVISOR SMART 40" KDL-40W655D SONY ['SONY' 'SONY                ']
# TELEVISOR SMART 40" UN40J5200 SAMSUNG ['SAMSUNG' 'SAMSUNG             ']
# REFRIGERADOR BRASTEMP 3PTS.BRO80ABBNA 540L BR ['WHIRLPOOL' 'WHIRLPOOL           ']
# LAVADORA SEINE 10,1KG 220V WF106U4SAWQFAZ BR ['SAMSUNG' 'SAMSUNG             ']
# REFRIGERADOR DC49A ELUX 220 BR ['ELECTROLUX' 'ELECTROLUX          ']
# LAVADORA ML60 LAVETE INTENSE REC ['SEB COMERCIAL' 'SEB COMERCIAL       ']
# SMARTPHONE LG K4 NOVO X230DS DB TITANIO ['LG' 'LG                  ']
# SMARTPHONE LG K10 POWER DB TITANIUM ['LG' 'LG                  ']
# VENTILADOR TUFAO 60 CM PAREDE PT ['LOREN SID' 'LOREN SID           ']
# BEBEDOURO EGC 35 B INOX NV ['ESMALTEC' 'ESMALTEC            ']
# RADIO CJ88 ABRALLK LG ['LG' 'LG                  ']
# SMARTPHONE SAMSUNG GAL J7 PRO J730 DB PT ['ALLIED' 'ALLIED              ']
# COLC CONFIDENCIAL 35CMX198CMX158CM SUPER LAS ['SFERA - PB' 'SFERA - PB          ']
# COLCHAO DUROSPRING VIP 138X188X30 ['PLUMATEX' 'PLUMATEX            ']
# TELEVISOR 32" DL3253 SEMP TCL ['SEMP TCL' '0']
# CONJ.SC-AKX700LBK SOM 3X1 PANASONIC ['PANASONIC' 'PANASONIC           ']
# TELEVISOR SMART 28" 28MT49S LG ['LG' 'LG                  ']
# LAVADORA AUTOMATICA NA-F140 B5WB PANASONIC ['PANASONIC' 'PANASONIC           ']
# FOGAO GAS 4BC.UTOP GLASS PTO ['ATLAS' 'ATLAS               ']
# TELEVISOR SMART 49" 4K 49UJ6565 LG ['LG' 'LG                  ']
# COLCHAO DUROSPRING VIP 158X198X30 ['PLUMATEX' 'PLUMATEX            ']
# RADIO CJ98 ABRALLK LG ['LG' 'LG                  ']
# COLC KING BEST 30CMX188CMX088 M.SUPER LASTI ['SFERA - PB' 'SFERA - PB          ']
# TELEVISOR SMART 49" 49LJ5550 LG ['LG' 'LG                  ']
# TELEVISOR SMART 32" UN32J4300 SAMSUNG ['SAMSUNG' 'SAMSUNG             ']
# VENTILADOR VF40 SILENCE FORCE CD RE ['SEB COMERCIAL' 'SEB COMERCIAL       ']
# TELEVISOR SMART 32" TC32ES600 PANASONIC ['PANASONIC' 'PANASONIC           ']
# ROUPEIRO 3PTS 6GAV NOGAL C/PES MAD F542-NO ['KAPPESBERG/CROME' 'KAPPESBERG/CROME    ' 'KAPPESBERG          '
#  'KAPPESBERG']
# MAQUINA DE COSTURA  B3 C/MOVEL 17 PC E BATTY ['ELGIN' 'ELGIN               ']
# FOGAO GAS 5BC.UTOP GLASS PTO ['ATLAS' 'ATLAS               ']
# COLCHAO RICHESSE NEW 38CMX198CMX158CM ['SFERA - PB' 'SFERA - PB          ']
# SMARTPHONE SAMSUNG GAL J7 PRO J730 DB DR ['ALLIED' 'ALLIED              ']
# SMARTPHONE SAMSUNG GAL J1 MINI DB DOURADO ['SIRI' 'SIRI                ']
# ROUPEIRO 6PTS 6GAV NOGAL MADE F546-NO ['KAPPESBERG/CROME' 'KAPPESBERG/CROME    ' 'KAPPESBERG          '
#  'KAPPESBERG']
# FREEZER HORIZONTAL EFH 350 220V BR ['ESMALTEC' 'ESMALTEC            ']
# CONJ.080 6 C.COPACABANA C ENC.TRI CZ PRA TP G ['UAI MOVEIS' 'UAI MOVEIS          ']
# REFRIGERADOR RCD 38 BR 220V ['ESMALTEC' 'ESMALTEC            ']
# VENTILADOR DE PAREDE 60CM ACO NEW P GR PR ['VENTISOL' 'VENTISOL            ']
# TELEVISOR SMART 43" 4K 43UJ6565 LG ['LG' 'LG                  ']
# REFRIGERADOR RCD 38 INOX ['ESMALTEC' 'ESMALTEC            ']
# REFRIGERADOR TF51X INOX ['ELECTROLUX' 'ELECTROLUX          ']
# REFRIGERADOR CONSUL 2PTS.CRM55ABBNA BR ['WHIRLPOOL' 'WHIRLPOOL           ']
# VENTILADOR 40CM NV-45 6P BR 220V ['MONDIAL' 'MONDIAL             ']
# TELEVISOR SMART 32" 32LJ600B LG ['LG' 'LG                  ']
# ESTOFADO ORION MARROM ['VIERO MOVEIS' 'VIERO MOVEIS        ']
# LAVADORA BRASTEMP BWH15ABBNA 15KG BR ['WHIRLPOOL' 'WHIRLPOOL           ']
# TELEVISOR SMART 43" TC43SV700 PANASONIC ['PANASONIC' 'PANASONIC           ']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-20431d602c5b> in <module>
#       2 print(df.loc[df['SUBCATEGORIA'] == 'ELETRO LINHA BRANCA']['COD_GRUPO'].unique())
#       3 for cat in df['PRODUTO'].unique():
# ----> 4     u = df.loc[df['PRODUTO'] == cat]['FORNECEDOR'].unique()
#       5     if(len(u) > 1):
#       6         print(cat, u)
#
# /Library/Python/3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# /Library/Python/3.8/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
#      31     @unpack_zerodim_and_defer("__ne__")
#
# /Library/Python/3.8/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    4946         rvalues = extract_array(other, extract_numpy=True)
#    4947
# -> 4948         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4949
#    4950         return self._construct_result(res_values, name=res_name)
#
# /Library/Python/3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     241
#     242     elif is_object_dtype(lvalues.dtype):
# --> 243         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     244
#     245     else:
#
# /Library/Python/3.8/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      53         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      54     else:
# ---> 55         result = libops.scalar_compare(x.ravel(), y, op)
#      56     return result.reshape(x.shape)
#      57
#
# KeyboardInterrupt:

# %% [markdown]
# ## Geração da tabela de dados geral
#
# Vendas de produtos por data

# %%
def get_dfg(general=True, keep_month=True):
    dfg = df.drop(columns=['COD_FILIAL', 'SIGLA', 'REGIAO', 'COD_PRODUTO', 'COD_GRUPO', 'CLASSIFICACAO', 'COD_FILIAL_', 'COD_ENTREGA', 'ENTREGA', 'ANO/MES', '1', '2', 'CD', '3', '4', 'SUBCATEGORIA', 'FORNECEDOR'])
    if general is True:
        dfg.drop(columns=['NOME'], inplace=True)
    if keep_month is False:
        dfg.drop(columns=['MES'], inplace=True)
    
    return dfg

dfg = get_dfg(general=False, keep_month=False)

index = pd.date_range(start='2018-01-01', end='2021-04-01', freq='D')
columns = dfg['PRODUTO'].unique()

df2 = pd.DataFrame(index=index, columns=columns)
df2.fillna(value=0, inplace=True)
df2.head()
# Out:
#             CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4  \
# 2018-01-01                                            0
# 2018-01-02                                            0
# 2018-01-03                                            0
# 2018-01-04                                            0
# 2018-01-05                                            0
#
#             REFRIGERADOR ROC 31 BR  TELEVISOR SMART 32" 32PHG5102 PHILIPS  \
# 2018-01-01                       0                                      0
# 2018-01-02                       0                                      0
# 2018-01-03                       0                                      0
# 2018-01-04                       0                                      0
# 2018-01-05                       0                                      0
#
#             TELEVISOR SMART 32" PH32E20DSGWA PHILCO  \
# 2018-01-01                                        0
# 2018-01-02                                        0
# 2018-01-03                                        0
# 2018-01-04                                        0
# 2018-01-05                                        0
#
#             UNIDADE EVAPORADORA 12000BTUS 42MACA12S5  \
# 2018-01-01                                         0
# 2018-01-02                                         0
# 2018-01-03                                         0
# 2018-01-04                                         0
# 2018-01-05                                         0
#
#             TELEVISOR SMART 32" KDL-32W655D SONY  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             TELEVISOR SMART 43" 43PFG5102 PHILIPS  \
# 2018-01-01                                      0
# 2018-01-02                                      0
# 2018-01-03                                      0
# 2018-01-04                                      0
# 2018-01-05                                      0
#
#             UNIDADE CONDENSADORA 12000BTUS 38KCX12S5  \
# 2018-01-01                                         0
# 2018-01-02                                         0
# 2018-01-03                                         0
# 2018-01-04                                         0
# 2018-01-05                                         0
#
#             TELEVISOR 40" L40D2900 SEMP TCL  \
# 2018-01-01                                0
# 2018-01-02                                0
# 2018-01-03                                0
# 2018-01-04                                0
# 2018-01-05                                0
#
#             SMARTPHONE SAMSUNG GAL J7 PRIME DB DOURADO  ...  \
# 2018-01-01                                           0  ...
# 2018-01-02                                           0  ...
# 2018-01-03                                           0  ...
# 2018-01-04                                           0  ...
# 2018-01-05                                           0  ...
#
#             FOGAO AGILE UP GLASS 4 BOCAS INOX  \
# 2018-01-01                                  0
# 2018-01-02                                  0
# 2018-01-03                                  0
# 2018-01-04                                  0
# 2018-01-05                                  0
#
#             FOGAO AGILE UP GLASS 5 BOCAS INOX  \
# 2018-01-01                                  0
# 2018-01-02                                  0
# 2018-01-03                                  0
# 2018-01-04                                  0
# 2018-01-05                                  0
#
#             VENTILADOR 30CM ECO 6PAS MESA BRONZE  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             SMARTPHONE MULTILASER F 32GB PRETO  \
# 2018-01-01                                   0
# 2018-01-02                                   0
# 2018-01-03                                   0
# 2018-01-04                                   0
# 2018-01-05                                   0
#
#             SMARTPHONE MULTILASER E LITE 32GB PRETO  BOX BLUE NEW 96X28X203  \
# 2018-01-01                                        0                       0
# 2018-01-02                                        0                       0
# 2018-01-03                                        0                       0
# 2018-01-04                                        0                       0
# 2018-01-05                                        0                       0
#
#             SMARTPHONE MULTILASER E LITE 32GB DOURADO  \
# 2018-01-01                                          0
# 2018-01-02                                          0
# 2018-01-03                                          0
# 2018-01-04                                          0
# 2018-01-05                                          0
#
#             AR CONDICIONADO 9000 BTU/H TAC-09CSA1 INV  \
# 2018-01-01                                          0
# 2018-01-02                                          0
# 2018-01-03                                          0
# 2018-01-04                                          0
# 2018-01-05                                          0
#
#             ESCORREDOR DE 16 PRATOS INOX 2099116  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             SMARTPHONE MULTILASER F 32GB DOURADO
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
# [5 rows x 7349 columns]

# %% [markdown]
# ### Criar os dataframes das lojas

# %%
stores = dfg['NOME'].unique()
stores_dfs = {}

for store in stores:
    stores_dfs[store] = pd.DataFrame(index=index, columns=columns)
    stores_dfs[store].fillna(value=0, inplace=True)

# %%
for row in dfg.itertuples():
    if(row[0] % 10000) == 0:
        print('%.2f%% DONE' % ((row[0] / dfg.shape[0]) * 100))
    # INDEX = 0
    # NOME = 1
    # PRODUTO = 2
    # QTD_VENDIDA = 3
    # DATA = 4
    stores_dfs[row[1]].loc[row[4], row[2]] = row[3]
# Out:
# 0.00% DONE
# 0.26% DONE
# 0.51% DONE
# 0.77% DONE
# 1.03% DONE
# 1.29% DONE
# 1.54% DONE
# 1.80% DONE
# 2.06% DONE
# 2.32% DONE
# 2.57% DONE
# 2.83% DONE
# 3.09% DONE
# 3.34% DONE
# 3.60% DONE
# 3.86% DONE
# 4.12% DONE
# 4.37% DONE
# 4.63% DONE
# 4.89% DONE
# 5.15% DONE
# 5.40% DONE
# 5.66% DONE
# 5.92% DONE
# 6.17% DONE
# 6.43% DONE
# 6.69% DONE
# 6.95% DONE
# 7.20% DONE
# 7.46% DONE
# 7.72% DONE
# 7.98% DONE
# 8.23% DONE
# 8.49% DONE
# 8.75% DONE
# 9.01% DONE
# 9.26% DONE
# 9.52% DONE
# 9.78% DONE
# 10.03% DONE
# 10.29% DONE
# 10.55% DONE
# 10.81% DONE
# 11.06% DONE
# 11.32% DONE
# 11.58% DONE
# 11.84% DONE
# 12.09% DONE
# 12.35% DONE
# 12.61% DONE
# 12.86% DONE
# 13.12% DONE
# 13.38% DONE
# 13.64% DONE
# 13.89% DONE
# 14.15% DONE
# 14.41% DONE
# 14.67% DONE
# 14.92% DONE
# 15.18% DONE
# 15.44% DONE
# 15.69% DONE
# 15.95% DONE
# 16.21% DONE
# 16.47% DONE
# 16.72% DONE
# 16.98% DONE
# 17.24% DONE
# 17.50% DONE
# 17.75% DONE
# 18.01% DONE
# 18.27% DONE
# 18.52% DONE
# 18.78% DONE
# 19.04% DONE
# 19.30% DONE
# 19.55% DONE
# 19.81% DONE
# 20.07% DONE
# 20.33% DONE
# 20.58% DONE
# 20.84% DONE
# 21.10% DONE
# 21.36% DONE
# 21.61% DONE
# 21.87% DONE
# 22.13% DONE
# 22.38% DONE
# 22.64% DONE
# 22.90% DONE
# 23.16% DONE
# 23.41% DONE
# 23.67% DONE
# 23.93% DONE
# 24.19% DONE
# 24.44% DONE
# 24.70% DONE
# 24.96% DONE
# 25.21% DONE
# 25.47% DONE
# 25.73% DONE
# 25.99% DONE
# 26.24% DONE
# 26.50% DONE
# 26.76% DONE
# 27.02% DONE
# 27.27% DONE
# 27.53% DONE
# 27.79% DONE
# 28.04% DONE
# 28.30% DONE
# 28.56% DONE
# 28.82% DONE
# 29.07% DONE
# 29.33% DONE
# 29.59% DONE
# 29.85% DONE
# 30.10% DONE
# 30.36% DONE
# 30.62% DONE
# 30.87% DONE
# 31.13% DONE
# 31.39% DONE
# 31.65% DONE
# 31.90% DONE
# 32.16% DONE
# 32.42% DONE
# 32.68% DONE
# 32.93% DONE
# 33.19% DONE
# 33.45% DONE
# 33.70% DONE
# 33.96% DONE
# 34.22% DONE
# 0.00% DONE
# 0.26% DONE
# 0.51% DONE
# 0.77% DONE
# 1.03% DONE
# 1.29% DONE
# 1.54% DONE
# 1.80% DONE
# 2.06% DONE
# 2.32% DONE
# 2.57% DONE
# 2.83% DONE
# 3.09% DONE
# 3.34% DONE
# 3.60% DONE
# 3.86% DONE
# 4.12% DONE
# 4.37% DONE
# 4.63% DONE
# 4.89% DONE
# 5.15% DONE
# 5.40% DONE
# 5.66% DONE
# 5.92% DONE
# 6.17% DONE
# 6.43% DONE
# 6.69% DONE
# 6.95% DONE
# 7.20% DONE
# 7.46% DONE
# 7.72% DONE
# 7.98% DONE
# 8.23% DONE
# 8.49% DONE
# 8.75% DONE
# 9.01% DONE
# 9.26% DONE
# 9.52% DONE
# 9.78% DONE
# 10.03% DONE
# 10.29% DONE
# 10.55% DONE
# 10.81% DONE
# 11.06% DONE
# 11.32% DONE
# 11.58% DONE
# 11.84% DONE
# 12.09% DONE
# 12.35% DONE
# 12.61% DONE
# 12.86% DONE
# 13.12% DONE
# 13.38% DONE
# 13.64% DONE
# 13.89% DONE
# 14.15% DONE
# 14.41% DONE
# 14.67% DONE
# 14.92% DONE
# 15.18% DONE
# 15.44% DONE
# 15.69% DONE
# 15.95% DONE
# 16.21% DONE
# 16.47% DONE
# 16.72% DONE
# 16.98% DONE
# 17.24% DONE
# 17.50% DONE
# 17.75% DONE
# 18.01% DONE
# 18.27% DONE
# 18.52% DONE
# 18.78% DONE
# 19.04% DONE
# 19.30% DONE
# 19.55% DONE
# 19.81% DONE
# 20.07% DONE
# 20.33% DONE
# 20.58% DONE
# 20.84% DONE
# 21.10% DONE
# 21.36% DONE
# 21.61% DONE
# 21.87% DONE
# 22.13% DONE
# 22.38% DONE
# 22.64% DONE
# 22.90% DONE
# 23.16% DONE
# 23.41% DONE
# 23.67% DONE
# 23.93% DONE
# 24.19% DONE
# 24.44% DONE
# 24.70% DONE
# 24.96% DONE
# 25.21% DONE
# 25.47% DONE
# 25.73% DONE
# 25.99% DONE
# 26.24% DONE
# 26.50% DONE
# 26.76% DONE
# 27.02% DONE
# 27.27% DONE
# 27.53% DONE
# 27.79% DONE
# 28.04% DONE
# 28.30% DONE
# 28.56% DONE
# 28.82% DONE
# 29.07% DONE
# 29.33% DONE
# 29.59% DONE
# 29.85% DONE
# 30.10% DONE
# 30.36% DONE
# 30.62% DONE
# 30.87% DONE
# 31.13% DONE
# 31.39% DONE
# 31.65% DONE
# 31.90% DONE
# 32.16% DONE
# 0.00% DONE
# 0.26% DONE
# 0.51% DONE
# 0.77% DONE
# 1.03% DONE
# 1.29% DONE
# 1.54% DONE
# 1.80% DONE
# 2.06% DONE
# 2.32% DONE
# 2.57% DONE
# 2.83% DONE
# 3.09% DONE
# 3.34% DONE
# 3.60% DONE
# 3.86% DONE
# 4.12% DONE
# 4.37% DONE
# 4.63% DONE
# 4.89% DONE
# 5.15% DONE
# 5.40% DONE
# 5.66% DONE
# 5.92% DONE
# 6.17% DONE
# 6.43% DONE
# 6.69% DONE
# 6.95% DONE
# 7.20% DONE
# 7.46% DONE
# 7.72% DONE
# 7.98% DONE
# 8.23% DONE
# 8.49% DONE
# 8.75% DONE
# 9.01% DONE
# 9.26% DONE
# 9.52% DONE
# 9.78% DONE
# 10.03% DONE
# 10.29% DONE
# 10.55% DONE
# 10.81% DONE
# 11.06% DONE
# 11.32% DONE
# 11.58% DONE
# 11.84% DONE
# 12.09% DONE
# 12.35% DONE
# 12.61% DONE
# 12.86% DONE
# 13.12% DONE
# 13.38% DONE
# 13.64% DONE
# 13.89% DONE
# 14.15% DONE
# 14.41% DONE
# 14.67% DONE
# 14.92% DONE
# 15.18% DONE
# 15.44% DONE
# 15.69% DONE
# 15.95% DONE
# 16.21% DONE
# 16.47% DONE
# 16.72% DONE
# 16.98% DONE
# 17.24% DONE
# 17.50% DONE
# 17.75% DONE
# 18.01% DONE
# 18.27% DONE
# 18.52% DONE
# 18.78% DONE
# 19.04% DONE
# 19.30% DONE
# 19.55% DONE
# 19.81% DONE
# 20.07% DONE
# 20.33% DONE
# 20.58% DONE
# 20.84% DONE
# 21.10% DONE
# 21.36% DONE
# 21.61% DONE
# 21.87% DONE
# 22.13% DONE
# 22.38% DONE
# 22.64% DONE
# 22.90% DONE
# 23.16% DONE
# 23.41% DONE
# 23.67% DONE
# 23.93% DONE
# 24.19% DONE
# 24.44% DONE
# 24.70% DONE
# 24.96% DONE
# 25.21% DONE
# 25.47% DONE
# 25.73% DONE
# 25.99% DONE
# 26.24% DONE
# 26.50% DONE
# 26.76% DONE
# 27.02% DONE
# 27.27% DONE
# 27.53% DONE
# 27.79% DONE
# 28.04% DONE
# 0.00% DONE
# 0.26% DONE
# 0.51% DONE
# 0.77% DONE
# 1.03% DONE
# 1.29% DONE
# 1.54% DONE
# 1.80% DONE
# 2.06% DONE
# 2.32% DONE
# 2.57% DONE
# 2.83% DONE
# 3.09% DONE
# 3.34% DONE
# 3.60% DONE
# 3.86% DONE
# 4.12% DONE
# 4.37% DONE
# 4.63% DONE
# 4.89% DONE
# 5.15% DONE

# %%
n
# Out:
# NOME                                                   Ico
# PRODUTO        CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4
# QTD_VENDIDA                                             27
# DATA                                   2018-02-27 00:00:00
# Name: 0, dtype: object

# %%
df2.head()
# Out:
#             CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4  \
# 2018-01-01                                            0
# 2018-01-02                                            0
# 2018-01-03                                            0
# 2018-01-04                                            0
# 2018-01-05                                            0
#
#             REFRIGERADOR ROC 31 BR  TELEVISOR SMART 32" 32PHG5102 PHILIPS  \
# 2018-01-01                       3                                      0
# 2018-01-02                       0                                      0
# 2018-01-03                       0                                      0
# 2018-01-04                       0                                      0
# 2018-01-05                       0                                      0
#
#             TELEVISOR SMART 32" PH32E20DSGWA PHILCO  \
# 2018-01-01                                        0
# 2018-01-02                                        0
# 2018-01-03                                        0
# 2018-01-04                                        0
# 2018-01-05                                        0
#
#             UNIDADE EVAPORADORA 12000BTUS 42MACA12S5  \
# 2018-01-01                                         0
# 2018-01-02                                         0
# 2018-01-03                                         0
# 2018-01-04                                         0
# 2018-01-05                                         0
#
#             TELEVISOR SMART 32" KDL-32W655D SONY  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             TELEVISOR SMART 43" 43PFG5102 PHILIPS  \
# 2018-01-01                                      0
# 2018-01-02                                      0
# 2018-01-03                                      0
# 2018-01-04                                      0
# 2018-01-05                                      0
#
#             UNIDADE CONDENSADORA 12000BTUS 38KCX12S5  \
# 2018-01-01                                         0
# 2018-01-02                                         0
# 2018-01-03                                         0
# 2018-01-04                                         0
# 2018-01-05                                         0
#
#             TELEVISOR 40" L40D2900 SEMP TCL  \
# 2018-01-01                                0
# 2018-01-02                                0
# 2018-01-03                                0
# 2018-01-04                                0
# 2018-01-05                                0
#
#             SMARTPHONE SAMSUNG GAL J7 PRIME DB DOURADO  ...  \
# 2018-01-01                                           0  ...
# 2018-01-02                                           0  ...
# 2018-01-03                                           0  ...
# 2018-01-04                                           0  ...
# 2018-01-05                                           0  ...
#
#             FOGAO AGILE UP GLASS 4 BOCAS INOX  \
# 2018-01-01                                  0
# 2018-01-02                                  0
# 2018-01-03                                  0
# 2018-01-04                                  0
# 2018-01-05                                  0
#
#             FOGAO AGILE UP GLASS 5 BOCAS INOX  \
# 2018-01-01                                  0
# 2018-01-02                                  0
# 2018-01-03                                  0
# 2018-01-04                                  0
# 2018-01-05                                  0
#
#             VENTILADOR 30CM ECO 6PAS MESA BRONZE  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             SMARTPHONE MULTILASER F 32GB PRETO  \
# 2018-01-01                                   0
# 2018-01-02                                   0
# 2018-01-03                                   0
# 2018-01-04                                   0
# 2018-01-05                                   0
#
#             SMARTPHONE MULTILASER E LITE 32GB PRETO  BOX BLUE NEW 96X28X203  \
# 2018-01-01                                        0                       0
# 2018-01-02                                        0                       0
# 2018-01-03                                        0                       0
# 2018-01-04                                        0                       0
# 2018-01-05                                        0                       0
#
#             SMARTPHONE MULTILASER E LITE 32GB DOURADO  \
# 2018-01-01                                          0
# 2018-01-02                                          0
# 2018-01-03                                          0
# 2018-01-04                                          0
# 2018-01-05                                          0
#
#             AR CONDICIONADO 9000 BTU/H TAC-09CSA1 INV  \
# 2018-01-01                                          0
# 2018-01-02                                          0
# 2018-01-03                                          0
# 2018-01-04                                          0
# 2018-01-05                                          0
#
#             ESCORREDOR DE 16 PRATOS INOX 2099116  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             SMARTPHONE MULTILASER F 32GB DOURADO
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
# [5 rows x 7349 columns]

# %%
p = s = 0
num_p = len(columns)
num_s = len(stores)

for store in ['Ico']: # store
    s += 1
    clear_output(wait=True)
    print("(%d/%d) %s" % (s, num_s, store))
    for product in columns: # columns
        group = dfg.loc[(dfg['PRODUTO'] == product) & (dfg['NOME'] == store)].groupby(['DATA']).sum()
        p += 1
        print("(%d/%d) %s" % (p, num_p, product))
        #clear_output(wait=True)
        i = 0
        for row in group.index:
            stores_dfs[store].loc[row][product] = group.iloc[i]['QTD_VENDIDA']
            i += 1
# Out:
# (1/57) Ico
# (1/7349) CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4
# (2/7349) REFRIGERADOR ROC 31 BR
# (3/7349) TELEVISOR SMART 32" 32PHG5102 PHILIPS
# (4/7349) TELEVISOR SMART 32" PH32E20DSGWA PHILCO
# (5/7349) UNIDADE EVAPORADORA 12000BTUS 42MACA12S5
# (6/7349) TELEVISOR SMART 32" KDL-32W655D SONY
# (7/7349) TELEVISOR SMART 43" 43PFG5102 PHILIPS
# (8/7349) UNIDADE CONDENSADORA 12000BTUS 38KCX12S5
# (9/7349) TELEVISOR 40" L40D2900 SEMP TCL
# (10/7349) SMARTPHONE SAMSUNG GAL J7 PRIME DB DOURADO
# (11/7349) SMARTPHONE SAMSUNG GAL J5 PRIME DB DOURADO
# (12/7349) TELEVISOR SMART 43" L43S4900FS SEMP TCL
# (13/7349) TELEVISOR SMART 48" KDL-48W655D SONY
# (14/7349) SMARTPHONE SAMSUNG GAL J5 PRIME DB ROSA
# (15/7349) REFRIGERADOR DB84 FROST FREE 598L BR
# (16/7349) TELEVISOR SMART 43" 43LJ5550 LG
# (17/7349) SMARTPHONE SAMSUNG GAL J5 PRIME DB PRETO
# (18/7349) TELEVISOR SMART 55" 4K QN55Q7FAMGXZD SAMSUNG
# (19/7349) TELEVISOR SMART 42" PH42F10DSGWAC PHILCO
# (20/7349) SMARTPHONE SAMSUNG GAL J2 PRIME 16GB TV DB DR
# (21/7349) TABLET NB269 M7 3G PLUS PRETO
# (22/7349) LAVADORA AUTOMATICA NA-F160 B5WB PANASONIC
# (23/7349) COLC KING BEST 30CMX198CMX158 M.SUPER LASTIC
# (24/7349) TELEVISOR SMART 49" TC49ES630 PANASONIC
# (25/7349) SMARTPHONE LG K10 NOVO DB TITANIUM
# (26/7349) REFRIGERADOR DC35A
# (27/7349) TELEVISOR 32" KDL-32R305B SONY
# (28/7349) FOGAO 4BC. BALI 4076 BR
# (29/7349) TELEVISOR SMART 49" UN49J5200 SAMSUNG
# (30/7349) VENTILADOR VFM2 SIL FORCE VE3230B4
# (31/7349) TELEVISOR 40" TC40D400B PANASONIC
# (32/7349) SMARTPHONE LG K10 NOVO DB PRETO
# (33/7349) SMARTPHONE LG K10 NOVO DB DOURADO
# (34/7349) SMARTPHONE LG K10 POWER DB DOURADO
# (35/7349) TELEVISOR 24" PH24N91D PHILCO
# (36/7349) REFRIGERADOR DFN39 BRANCO
# (37/7349) COLC KING BEST 30CMX188CMX138 M.SUPER LASTIC
# (38/7349) SMARTPHONE SAMSUNG GAL J2 PRIME 16GB TV DB RS
# (39/7349) SMARTPHONE SAMSUNG GAL J1 J120 DB PRETO
# (40/7349) FREEZER HORIZONTAL EFH 500 220V BR
# (41/7349) REFRIGERADOR NR-BT47BD2XB NO FROST 435L ACO E
# (42/7349) SMARTPHONE SAMSUNG GAL J5 PRO DB DOURADO
# (43/7349) SMARTPHONE SAMSUNG GAL J2 PRIME 16GB TV DB PT
# (44/7349) REFRIGERADOR NR-BT40BD1WB 387L BCO
# (45/7349) TELEVISOR SMART 40" KDL-40W655D SONY
# (46/7349) LAVA E SECA SEINE 10,1KG 220V WD106UHSAWQFAZ
# (47/7349) SMARTPHONE SAMSUNG GAL J5 PRO DB PRETO
# (48/7349) TELEVISOR SMART 40" UN40J5200 SAMSUNG
# (49/7349) TELEVISOR 32" TC32D400 PANASONIC
# (50/7349) REFRIGERADOR BRASTEMP 3PTS.BRO80ABBNA 540L BR
# (51/7349) TELEVISOR 28" PH28D27D PHILCO
# (52/7349) LAVADORA SEINE 10,1KG 220V WF106U4SAWQFAZ BR
# (53/7349) REFRIGERADOR DC49A ELUX 220 BR
# (54/7349) LAVADORA ML60 LAVETE INTENSE REC
# (55/7349) CONJ.SC-AKX880LBK PANASONIC
# (56/7349) SMARTPHONE LG K4 NOVO X230DS DB TITANIO
# (57/7349) SMARTPHONE LG K10 POWER DB TITANIUM
# (58/7349) COLCHAO LUXOR 088X188X25
# (59/7349) REFRIGERADOR DB84X FROST FREE BOTTOM 598L
# (60/7349) SMARTPHONE SAMSUNG GAL J7 PRIME DB PRETO
# (61/7349) NOTEBOOK MULTILASER LEGACY PC 101 32G PT
# (62/7349) REFRIGERADOR NR-BB52PV2XB
# (63/7349) VENTILADOR TUFAO 60 CM PAREDE PT
# (64/7349) SMARTPHONE SAMSUNG GAL J1 J120 DB DOURADO
# (65/7349) BEBEDOURO EGC 35 B INOX NV
# (66/7349) RADIO CJ88 ABRALLK LG
# (67/7349) SMARTPHONE SAMSUNG GAL J7 PRO J730 DB PT
# (68/7349) REFRIGERADOR ATIVE BRM50NKBNA EVOX
# (69/7349) COLC CONFIDENCIAL 35CMX198CMX158CM SUPER LAS
# (70/7349) TELEVISOR SMART 43" TC43ES630 PANASONIC
# (71/7349) COLCHAO DUROSPRING VIP 138X188X30
# (72/7349) TELEVISOR 32" DL3253 SEMP TCL
# (73/7349) REFRIGERADOR DB83X
# (74/7349) CONJ.SC-AKX700LBK SOM 3X1 PANASONIC
# (75/7349) TELEVISOR SMART 28" 28MT49S LG
# (76/7349) LAVADORA AUTOMATICA NA-F140 B5WB PANASONIC
# (77/7349) FOGAO GAS 4BC.UTOP GLASS PTO
# (78/7349) TELEVISOR SMART 49" 4K 49UJ6565 LG
# (79/7349) REFRIGERADOR BRASTEMP BRM 50 NBBNA
# (80/7349) REFRIGERADOR 2P RT46K6361SL/BZ FF 453L INOX
# (81/7349) COLCHAO DUROSPRING VIP 158X198X30
# (82/7349) TELEVISOR 40" KDL-40R355B SONY
# (83/7349) RADIO CJ98 ABRALLK LG
# (84/7349) COLC KING BEST 30CMX188CMX088 M.SUPER LASTI
# (85/7349) TELEVISOR SMART 49" 49LJ5550 LG
# (86/7349) TELEVISOR SMART 32" UN32J4300 SAMSUNG
# (87/7349) VENTILADOR VF40 SILENCE FORCE CD RE
# (88/7349) UNIDADE EXT.CA VE09F 220V 60 1F
# (89/7349) SMARTPHONE SAMSUNG GAL J7 NEO DB PRETO
# (90/7349) TELEVISOR 32" UN32J4000 SAMSUNG
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-18a605de9aca> in <module>
#       8     print("(%d/%d) %s" % (s, num_s, store))
#       9     for product in columns: # columns
# ---> 10         group = dfg.loc[(dfg['PRODUTO'] == product) & (dfg['NOME'] == store)].groupby(['DATA']).sum()
#      11         p += 1
#      12         print("(%d/%d) %s" % (p, num_p, product))
#
# /Library/Python/3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# /Library/Python/3.8/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
#      31     @unpack_zerodim_and_defer("__ne__")
#
# /Library/Python/3.8/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    4946         rvalues = extract_array(other, extract_numpy=True)
#    4947
# -> 4948         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4949
#    4950         return self._construct_result(res_values, name=res_name)
#
# /Library/Python/3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     241
#     242     elif is_object_dtype(lvalues.dtype):
# --> 243         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     244
#     245     else:
#
# /Library/Python/3.8/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      53         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      54     else:
# ---> 55         result = libops.scalar_compare(x.ravel(), y, op)
#      56     return result.reshape(x.shape)
#      57
#
# KeyboardInterrupt:

# %%
a[(a['NOME'] == 'Ico') & (a['PRODUTO'] == 'CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4')]
# Out:
#           DATA              NOME  QTD_VENDIDA
# 0   2018-01-03        Mamanguape            1
# 1   2018-01-04    Aristides Lobo            1
# 2   2018-01-04          Cabedelo            2
# 3   2018-01-04  Campina Grande I            2
# 4   2018-01-04         Esperanca            1
# ..         ...               ...          ...
# 624 2020-07-28    Aristides Lobo            2
# 625 2020-07-31    Aristides Lobo            1
# 626 2020-08-28        Lagoa Seca            1
# 627 2020-09-01    Aristides Lobo            1
# 628 2020-11-20          Cabedelo            1
#
# [629 rows x 3 columns]

# %%
for (k, v) in stores_dfs.items():
    v.to_csv('data/' + k + '.csv')

# %%
p = 0
for product in columns:
    p += 1
    group = dfg.loc[dfg['PRODUTO'] == product].groupby(['DATA']).sum()
    clear_output(wait=True)
    print(p, product)
    i = 0
    for row in group.index:
        df2.loc[row][product] = group.iloc[i]['QTD_VENDIDA']
        i += 1
# Out:
# 7349 SMARTPHONE MULTILASER F 32GB DOURADO

# %%
df2.head()
# Out:
#             CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4  \
# 2018-01-01                                            0
# 2018-01-02                                            0
# 2018-01-03                                            1
# 2018-01-04                                           25
# 2018-01-05                                           25
#
#             REFRIGERADOR ROC 31 BR  TELEVISOR SMART 32" 32PHG5102 PHILIPS  \
# 2018-01-01                       0                                      0
# 2018-01-02                      10                                      0
# 2018-01-03                       9                                      0
# 2018-01-04                       5                                      0
# 2018-01-05                       1                                      0
#
#             TELEVISOR SMART 32" PH32E20DSGWA PHILCO  \
# 2018-01-01                                        0
# 2018-01-02                                        0
# 2018-01-03                                        0
# 2018-01-04                                        0
# 2018-01-05                                        0
#
#             UNIDADE EVAPORADORA 12000BTUS 42MACA12S5  \
# 2018-01-01                                         0
# 2018-01-02                                        10
# 2018-01-03                                        10
# 2018-01-04                                         9
# 2018-01-05                                        10
#
#             TELEVISOR SMART 32" KDL-32W655D SONY  \
# 2018-01-01                                     0
# 2018-01-02                                    23
# 2018-01-03                                    17
# 2018-01-04                                     8
# 2018-01-05                                    18
#
#             TELEVISOR SMART 43" 43PFG5102 PHILIPS  \
# 2018-01-01                                      0
# 2018-01-02                                      0
# 2018-01-03                                      0
# 2018-01-04                                      0
# 2018-01-05                                      0
#
#             UNIDADE CONDENSADORA 12000BTUS 38KCX12S5  \
# 2018-01-01                                         0
# 2018-01-02                                        10
# 2018-01-03                                        10
# 2018-01-04                                         9
# 2018-01-05                                        10
#
#             TELEVISOR 40" L40D2900 SEMP TCL  \
# 2018-01-01                                0
# 2018-01-02                                9
# 2018-01-03                                4
# 2018-01-04                                9
# 2018-01-05                                9
#
#             SMARTPHONE SAMSUNG GAL J7 PRIME DB DOURADO  ...  \
# 2018-01-01                                           0  ...
# 2018-01-02                                          35  ...
# 2018-01-03                                          28  ...
# 2018-01-04                                           7  ...
# 2018-01-05                                           3  ...
#
#             FOGAO AGILE UP GLASS 4 BOCAS INOX  \
# 2018-01-01                                  0
# 2018-01-02                                  0
# 2018-01-03                                  0
# 2018-01-04                                  0
# 2018-01-05                                  0
#
#             FOGAO AGILE UP GLASS 5 BOCAS INOX  \
# 2018-01-01                                  0
# 2018-01-02                                  0
# 2018-01-03                                  0
# 2018-01-04                                  0
# 2018-01-05                                  0
#
#             VENTILADOR 30CM ECO 6PAS MESA BRONZE  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             SMARTPHONE MULTILASER F 32GB PRETO  \
# 2018-01-01                                   0
# 2018-01-02                                   0
# 2018-01-03                                   0
# 2018-01-04                                   0
# 2018-01-05                                   0
#
#             SMARTPHONE MULTILASER E LITE 32GB PRETO  BOX BLUE NEW 96X28X203  \
# 2018-01-01                                        0                       0
# 2018-01-02                                        0                       0
# 2018-01-03                                        0                       0
# 2018-01-04                                        0                       0
# 2018-01-05                                        0                       0
#
#             SMARTPHONE MULTILASER E LITE 32GB DOURADO  \
# 2018-01-01                                          0
# 2018-01-02                                          0
# 2018-01-03                                          0
# 2018-01-04                                          0
# 2018-01-05                                          0
#
#             AR CONDICIONADO 9000 BTU/H TAC-09CSA1 INV  \
# 2018-01-01                                          0
# 2018-01-02                                          0
# 2018-01-03                                          0
# 2018-01-04                                          0
# 2018-01-05                                          0
#
#             ESCORREDOR DE 16 PRATOS INOX 2099116  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             SMARTPHONE MULTILASER F 32GB DOURADO
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
# [5 rows x 7349 columns]

# %%
df2.to_csv('geral.csv')

# %% [markdown]
# ## Geração de dicionários de fornecedores, grupos e classificações

# %%
df['SUBCATEGORIA'] = df['SUBCATEGORIA'].apply(lambda x : x.strip())
df['FORNECEDOR'] = df['FORNECEDOR'].apply(lambda x : x.strip())
df['CLASSIFICACAO'] = df['CLASSIFICACAO'].apply(lambda x : x.strip())

# %%
sub_dict = {}
man_dict = {}
clas_dict = {}
p = 0
for product in columns:
    p += 1
    clear_output(wait=True)
    print(p, product)
    
    subs = df.loc[df['PRODUTO'] == product]['SUBCATEGORIA'].unique()
    mans = df.loc[df['PRODUTO'] == product]['FORNECEDOR'].unique()
    clas = df.loc[df['PRODUTO'] == product]['CLASSIFICACAO'].unique()
    
    for sub in subs:
        if sub in sub_dict:
            sub_dict[sub].add(product)
        else:
            sub_dict[sub] = {product}
    for man in mans:
        if man in man_dict:
            man_dict[man].add(product)
        else:
            man_dict[man] = {product}
    for clas in clas_dict:
        if clas in clas_dict:
            clas_dict[clas].add(product)
        else:
            clas_dict[clas] = {product}
# Out:
# 7349 SMARTPHONE MULTILASER F 32GB DOURADO

# %%
import json
with open('fornecedores.json', 'w') as fp:
    json.dump(sub_dict2, fp)

# %%
sub_dict2 = {}
for key in man_dict.keys():
    sub_dict2[key] = list(man_dict[key])

# %%
df.columns
# Out:
# Index(['COD_FILIAL', 'SIGLA', 'NOME', 'REGIAO', 'COD_PRODUTO', 'PRODUTO',
#        'COD_GRUPO', 'CLASSIFICACAO', 'QTD_VENDIDA', 'DATA', 'COD_FILIAL_',
#        'COD_ENTREGA', 'ENTREGA', 'ANO/MES', 'MES', '1', '2', 'CD', '3', '4',
#        'SUBCATEGORIA', 'FORNECEDOR'],
#       dtype='object')

# %%
df['NOME'].unique()
# Out:
# array(['Ico', 'Jacobina', 'Lagoa', 'Campina Grande I', 'Bayeux',
#        'Esperanca', 'Irece I', 'Mangabeira Shopping', 'Patos I', 'Matriz',
#        'Patos II', 'Campina Grande III', 'Itambe', 'Campina Grande II',
#        'Mangabeira', 'Aristides Lobo', 'Sape', 'Sta. Rita', 'Iguatu',
#        'Pombal', 'Itaporanga', 'Mamanguape', 'Sousa I', 'Timbauba',
#        'Joao Dourado', 'Goiana', 'Cuite', 'Queimadas', 'Irece II',
#        'Solanea', 'Guarabira', 'Cabedelo', 'Alagoa Grande', 'AREIA',
#        'Bancarios', 'Sousa II', 'Barao', 'Soledade', 'Guarabira II',
#        'Goiana 2', 'Geisel', 'Picui', 'Alhandra', 'Itabaiana',
#        'Lagoa Seca', 'Campina Grande IV', 'Monteiro', 'Patos III',
#        'Pianco', 'Sto. Elias', 'CD Cabedelo', 'Monteiro 2', 'Caruaru',
#        'Manaira', 'CABEDELO BR', 'Patos IV', 'teste'], dtype=object)

# %% [markdown]
# ## Processamento de dados de estoque

# %%
import pandas as pd

dfs = []
for month in ['JAN', 'FEB', 'MAR']:
    dfs.append(pd.read_csv('./2021/' + month +'.txt', delimiter=';', header=None))

df = pd.concat(dfs)

# %%
df.columns = ['Chave Filial + Produto',
'Código Filial',
'Código Produto é com 6 caracteres',
'Descrição de produto',
'Ponto de reposição',
'A classificar',
'Saldo do produto',
'Qtd Reserva',
'Saldo disponível',
'Dia',
'Filial + Código Produto + Dia (Chave primária)',
'CD de abastecimento'
]

# %%
df = df.astype({"Dia": str})

df['Dia'] = df['Dia'].apply(lambda x : x[:4] + '-' + x[4:6] + '-' + x[6:])
df['Dia'] = pd.to_datetime(df['Dia'])

# %%
len(df['Descrição de produto'].unique())
# Out:
# 4572

# %%
df_aux = pd.read_csv('geral.csv', index_col=0)

# %%
df['Dia'].sort_values(ascending=False)
# Out:
# 811206   2021-03-23
# 656842   2021-03-23
# 657426   2021-03-23
# 327029   2021-03-23
# 95031    2021-03-23
#             ...
# 810733   2021-01-04
# 341314   2021-01-04
# 146010   2021-01-04
# 38635    2021-01-04
# 459106   2021-01-04
# Name: Dia, Length: 2826941, dtype: datetime64[ns]

# %%
df[df['Dia'] == '2021-03-15'].groupby('Descrição de produto').sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c82643906f0e> in <module>
# ----> 1 df[df['Dia'] == '2021-03-15'].groupby('Descrição de produto').sum()
#
# NameError: name 'df' is not defined
