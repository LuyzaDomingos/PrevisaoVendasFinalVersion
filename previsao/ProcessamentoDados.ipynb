# %%
import pandas as pd
from IPython.display import clear_output

dfs = []
for txt in ['2018.txt', '2019.txt', '2020.txt', '2021.txt']:
    df = pd.read_csv(txt, delimiter=';', encoding = 'cp1252')
    df.columns = ['COD_FILIAL', 'SIGLA', 'NOME', 'REGIAO', 'COD_PRODUTO', 'PRODUTO', 'COD_GRUPO', 'CLASSIFICACAO', 'QTD_VENDIDA', 'DATA', 'COD_FILIAL_', 'COD_ENTREGA', 'ENTREGA', 'ANO/MES', 'MES', '1', '2', 'CD', '3', '4', 'SUBCATEGORIA', 'FORNECEDOR']
    df['DATA'] = pd.to_datetime(df['DATA'])
    dfs.append(df)
    
df = pd.concat(dfs)

df.head()
# Out:
# /Users/david/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/david/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    COD_FILIAL SIGLA      NOME   REGIAO  COD_PRODUTO  \
# 0          19   ICO       Ico   SERTAO        23161
# 1          21   JCB  Jacobina    BAHIA        19405
# 2          13   JPL     Lagoa  LITORAL        24575
# 3          13   JPL     Lagoa  LITORAL        24555
# 4          19   ICO       Ico   SERTAO        22929
#
#                                        PRODUTO  COD_GRUPO  \
# 0  CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4          3
# 1                       REFRIGERADOR ROC 31 BR          3
# 2        TELEVISOR SMART 32" 32PHG5102 PHILIPS          5
# 3      TELEVISOR SMART 32" PH32E20DSGWA PHILCO          5
# 4     UNIDADE EVAPORADORA 12000BTUS 42MACA12S5          3
#
#                             CLASSIFICACAO  QTD_VENDIDA       DATA  ...  \
# 0  ELETRO AR E VENTILACAO AR CONDICIONADO           27 2018-02-27  ...
# 1     ELETRO ELETRODOMESTICO REFRIGERADOR           29 2018-05-02  ...
# 2          TECNOLOGIA TV E VIDEO SMART TV           16 2018-02-23  ...
# 3          TECNOLOGIA TV E VIDEO SMART TV           17 2018-02-28  ...
# 4  ELETRO AR E VENTILACAO AR CONDICIONADO           22 2018-02-27  ...
#
#                  ENTREGA  ANO/MES        MES    1     2   CD         3  \
# 0         Pega/Não Monta   201802  FEVEREIRO  NaN  2018  CJZ  19023161
# 1         Pega/Não Monta   201802  FEVEREIRO  NaN  2018  CJZ  21019405
# 2  Não Entrega/Não Monta   201802  FEVEREIRO  NaN  2018  CBO  13024575
# 3  Não Entrega/Não Monta   201802  FEVEREIRO  NaN  2018  CBO  13024555
# 4         Pega/Não Monta   201802  FEVEREIRO  NaN  2018  CJZ  19022929
#
#                     4         SUBCATEGORIA       FORNECEDOR
# 0  1902316127/02/2018  ELETRO LINHA BRANCA         VENTISOL
# 1  2101940505/02/2018  ELETRO LINHA BRANCA         ESMALTEC
# 2  1302457523/02/2018      ELETRO TV E SOM  ENVISION MANAUS
# 3  1302455528/02/2018      ELETRO TV E SOM           PHILCO
# 4  1902292927/02/2018  ELETRO LINHA BRANCA         CLIMAZON
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Geração da tabela de dados geral
#
# Vendas de produtos por data

# %%
dfg = df.drop(columns=['COD_FILIAL', 'SIGLA', 'NOME', 'REGIAO', 'COD_PRODUTO', 'COD_GRUPO', 'CLASSIFICACAO', 'COD_FILIAL_', 'COD_ENTREGA', 'ENTREGA', 'ANO/MES', 'MES', '1', '2', 'CD', '3', '4', 'SUBCATEGORIA', 'FORNECEDOR'])

index = pd.date_range(start='2018-01-01', end='2021-03-12', freq='D')
columns = dfg['PRODUTO'].unique()

df2 = pd.DataFrame(index=index, columns=columns)
df2.fillna(value=0, inplace=True)
df2.head()
# Out:
#             CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4  \
# 2018-01-01                                            0
# 2018-01-02                                            0
# 2018-01-03                                            0
# 2018-01-04                                            0
# 2018-01-05                                            0
#
#             REFRIGERADOR ROC 31 BR  TELEVISOR SMART 32" 32PHG5102 PHILIPS  \
# 2018-01-01                       0                                      0
# 2018-01-02                       0                                      0
# 2018-01-03                       0                                      0
# 2018-01-04                       0                                      0
# 2018-01-05                       0                                      0
#
#             TELEVISOR SMART 32" PH32E20DSGWA PHILCO  \
# 2018-01-01                                        0
# 2018-01-02                                        0
# 2018-01-03                                        0
# 2018-01-04                                        0
# 2018-01-05                                        0
#
#             UNIDADE EVAPORADORA 12000BTUS 42MACA12S5  \
# 2018-01-01                                         0
# 2018-01-02                                         0
# 2018-01-03                                         0
# 2018-01-04                                         0
# 2018-01-05                                         0
#
#             TELEVISOR SMART 32" KDL-32W655D SONY  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             TELEVISOR SMART 43" 43PFG5102 PHILIPS  \
# 2018-01-01                                      0
# 2018-01-02                                      0
# 2018-01-03                                      0
# 2018-01-04                                      0
# 2018-01-05                                      0
#
#             UNIDADE CONDENSADORA 12000BTUS 38KCX12S5  \
# 2018-01-01                                         0
# 2018-01-02                                         0
# 2018-01-03                                         0
# 2018-01-04                                         0
# 2018-01-05                                         0
#
#             TELEVISOR 40" L40D2900 SEMP TCL  \
# 2018-01-01                                0
# 2018-01-02                                0
# 2018-01-03                                0
# 2018-01-04                                0
# 2018-01-05                                0
#
#             SMARTPHONE SAMSUNG GAL J7 PRIME DB DOURADO  ...  \
# 2018-01-01                                           0  ...
# 2018-01-02                                           0  ...
# 2018-01-03                                           0  ...
# 2018-01-04                                           0  ...
# 2018-01-05                                           0  ...
#
#             FOGAO AGILE UP GLASS 4 BOCAS INOX  \
# 2018-01-01                                  0
# 2018-01-02                                  0
# 2018-01-03                                  0
# 2018-01-04                                  0
# 2018-01-05                                  0
#
#             FOGAO AGILE UP GLASS 5 BOCAS INOX  \
# 2018-01-01                                  0
# 2018-01-02                                  0
# 2018-01-03                                  0
# 2018-01-04                                  0
# 2018-01-05                                  0
#
#             VENTILADOR 30CM ECO 6PAS MESA BRONZE  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             SMARTPHONE MULTILASER F 32GB PRETO  \
# 2018-01-01                                   0
# 2018-01-02                                   0
# 2018-01-03                                   0
# 2018-01-04                                   0
# 2018-01-05                                   0
#
#             SMARTPHONE MULTILASER E LITE 32GB PRETO  BOX BLUE NEW 96X28X203  \
# 2018-01-01                                        0                       0
# 2018-01-02                                        0                       0
# 2018-01-03                                        0                       0
# 2018-01-04                                        0                       0
# 2018-01-05                                        0                       0
#
#             SMARTPHONE MULTILASER E LITE 32GB DOURADO  \
# 2018-01-01                                          0
# 2018-01-02                                          0
# 2018-01-03                                          0
# 2018-01-04                                          0
# 2018-01-05                                          0
#
#             AR CONDICIONADO 9000 BTU/H TAC-09CSA1 INV  \
# 2018-01-01                                          0
# 2018-01-02                                          0
# 2018-01-03                                          0
# 2018-01-04                                          0
# 2018-01-05                                          0
#
#             ESCORREDOR DE 16 PRATOS INOX 2099116  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             SMARTPHONE MULTILASER F 32GB DOURADO
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
# [5 rows x 7349 columns]

# %%
p = 0
for product in columns:
    p += 1
    group = dfg.loc[dfg['PRODUTO'] == product].groupby(['DATA']).sum()
    clear_output(wait=True)
    print(p, product)
    i = 0
    for row in group.index:
        df2.loc[row][product] = group.iloc[i]['QTD_VENDIDA']
        i += 1
# Out:
# 7349 SMARTPHONE MULTILASER F 32GB DOURADO

# %%
df2.head()
# Out:
#             CONDICIONADOR DE AR TIPO SPLIT FIT CCSF9-R4  \
# 2018-01-01                                            0
# 2018-01-02                                            0
# 2018-01-03                                            0
# 2018-01-04                                            0
# 2018-01-05                                            0
#
#             REFRIGERADOR ROC 31 BR  TELEVISOR SMART 32" 32PHG5102 PHILIPS  \
# 2018-01-01                       0                                      0
# 2018-01-02                      14                                      7
# 2018-01-03                       8                                     16
# 2018-01-04                       0                                      0
# 2018-01-05                       0                                      0
#
#             TELEVISOR SMART 32" PH32E20DSGWA PHILCO  \
# 2018-01-01                                        0
# 2018-01-02                                        0
# 2018-01-03                                       37
# 2018-01-04                                        0
# 2018-01-05                                        0
#
#             UNIDADE EVAPORADORA 12000BTUS 42MACA12S5  \
# 2018-01-01                                         0
# 2018-01-02                                         2
# 2018-01-03                                         3
# 2018-01-04                                         0
# 2018-01-05                                         0
#
#             TELEVISOR SMART 32" KDL-32W655D SONY  \
# 2018-01-01                                     0
# 2018-01-02                                    45
# 2018-01-03                                    11
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             TELEVISOR SMART 43" 43PFG5102 PHILIPS  \
# 2018-01-01                                      0
# 2018-01-02                                      0
# 2018-01-03                                      6
# 2018-01-04                                      0
# 2018-01-05                                      0
#
#             UNIDADE CONDENSADORA 12000BTUS 38KCX12S5  \
# 2018-01-01                                         0
# 2018-01-02                                         2
# 2018-01-03                                         3
# 2018-01-04                                         0
# 2018-01-05                                         0
#
#             TELEVISOR 40" L40D2900 SEMP TCL  \
# 2018-01-01                                0
# 2018-01-02                                2
# 2018-01-03                                5
# 2018-01-04                                1
# 2018-01-05                                0
#
#             SMARTPHONE SAMSUNG GAL J7 PRIME DB DOURADO  ...  \
# 2018-01-01                                           0  ...
# 2018-01-02                                          32  ...
# 2018-01-03                                          33  ...
# 2018-01-04                                           2  ...
# 2018-01-05                                           2  ...
#
#             FOGAO AGILE UP GLASS 4 BOCAS INOX  \
# 2018-01-01                                  0
# 2018-01-02                                  0
# 2018-01-03                                  0
# 2018-01-04                                  0
# 2018-01-05                                  0
#
#             FOGAO AGILE UP GLASS 5 BOCAS INOX  \
# 2018-01-01                                  0
# 2018-01-02                                  0
# 2018-01-03                                  0
# 2018-01-04                                  0
# 2018-01-05                                  0
#
#             VENTILADOR 30CM ECO 6PAS MESA BRONZE  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             SMARTPHONE MULTILASER F 32GB PRETO  \
# 2018-01-01                                   0
# 2018-01-02                                   0
# 2018-01-03                                   0
# 2018-01-04                                   0
# 2018-01-05                                   0
#
#             SMARTPHONE MULTILASER E LITE 32GB PRETO  BOX BLUE NEW 96X28X203  \
# 2018-01-01                                        0                       0
# 2018-01-02                                        0                       0
# 2018-01-03                                        0                       0
# 2018-01-04                                        0                       0
# 2018-01-05                                        0                       0
#
#             SMARTPHONE MULTILASER E LITE 32GB DOURADO  \
# 2018-01-01                                          0
# 2018-01-02                                          0
# 2018-01-03                                          0
# 2018-01-04                                          0
# 2018-01-05                                          0
#
#             AR CONDICIONADO 9000 BTU/H TAC-09CSA1 INV  \
# 2018-01-01                                          0
# 2018-01-02                                          0
# 2018-01-03                                          0
# 2018-01-04                                          0
# 2018-01-05                                          0
#
#             ESCORREDOR DE 16 PRATOS INOX 2099116  \
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
#             SMARTPHONE MULTILASER F 32GB DOURADO
# 2018-01-01                                     0
# 2018-01-02                                     0
# 2018-01-03                                     0
# 2018-01-04                                     0
# 2018-01-05                                     0
#
# [5 rows x 7349 columns]

# %%
df2.to_csv('geral.csv')

# %% [markdown]
# ## Geração de dicionários de fornecedores, grupos e classificações

# %%
df['SUBCATEGORIA'] = df['SUBCATEGORIA'].apply(lambda x : x.strip())
df['FORNECEDOR'] = df['FORNECEDOR'].apply(lambda x : x.strip())
df['CLASSIFICACAO'] = df['CLASSIFICACAO'].apply(lambda x : x.strip())

# %%
sub_dict = {}
man_dict = {}
clas_dict = {}
p = 0
for product in columns:
    p += 1
    clear_output(wait=True)
    print(p, product)
    
    subs = df.loc[df['PRODUTO'] == product]['SUBCATEGORIA'].unique()
    mans = df.loc[df['PRODUTO'] == product]['FORNECEDOR'].unique()
    clas = df.loc[df['PRODUTO'] == product]['CLASSIFICACAO'].unique()
    
    for sub in subs:
        if sub in sub_dict:
            sub_dict[sub].add(product)
        else:
            sub_dict[sub] = {product}
    for man in mans:
        if man in man_dict:
            man_dict[man].add(product)
        else:
            man_dict[man] = {product}
    for clas in clas_dict:
        if clas in clas_dict:
            clas_dict[clas].add(product)
        else:
            clas_dict[clas] = {product}
# Out:
# 7349 SMARTPHONE MULTILASER F 32GB DOURADO

# %%
import json
with open('fornecedores.json', 'w') as fp:
    json.dump(sub_dict2, fp)

# %%
sub_dict2 = {}
for key in man_dict.keys():
    sub_dict2[key] = list(man_dict[key])
